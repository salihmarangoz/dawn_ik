# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Draw Circle

# %%
# params
roll,pitch,yaw = 0, np.pi/2, np.pi/2
c_x, c_y, c_z, c_r = 0.2, -0.4, 1.5, 0.18
header = "# timestamp x y z roll pitch yaw"
num_points = 1000
max_time = 30.0
filename = "circle_yz.txt"

x = []
y = []
z = []
for theta in np.linspace(0, -np.pi*2, num_points):
    x.append(c_x)
    y.append(c_r*np.sin(theta) + c_y)
    z.append(c_r*np.cos(theta) + c_z)

roll = np.repeat(roll, num_points)
pitch = np.repeat(pitch, num_points)
yaw = np.repeat(yaw, num_points)
t = np.linspace(0, max_time, num_points)
output = np.stack([t,x,y,z,roll,pitch,yaw])

with open("repair/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

# with open("lite6/" + filename, 'w', encoding='UTF8', newline='') as f:
#     f.write(header + "\n")
#     writer = csv.writer(f, delimiter =' ')
#     writer.writerows(output.T)

# %%
# params
roll,pitch,yaw = 0, np.pi/2, np.pi/2
c_x, c_y, c_z, c_r = 0.25, 0.0, 0.25, 0.18
header = "# timestamp x y z roll pitch yaw"
num_points = 1000
max_time = 30.0
filename = "circle_xy.txt"

x = []
y = []
z = []
for theta in np.linspace(0, -np.pi*2, num_points):
    x.append(c_r*np.sin(theta) + c_x)
    y.append(c_r*np.cos(theta) + c_y)
    z.append(c_z)

roll = np.repeat(roll, num_points)
pitch = np.repeat(pitch, num_points)
yaw = np.repeat(yaw, num_points)
t = np.linspace(0, max_time, num_points)
output = np.stack([t,x,y,z,roll,pitch,yaw])

with open("mick/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

with open("lite6/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

# %% [markdown]
# ## Draw Eight

# %%
# params
roll,pitch,yaw = 0, np.pi/2, np.pi/2
c_x, c_y, c_z, c_r = 0.2, 0.0, 0.3, 0.1
header = "# timestamp x y z roll pitch yaw"
num_points = 1000
max_time = 50.0
filename = "eight_yz.txt"

x = []
y = []
z = []
for theta in np.linspace(np.pi*3, np.pi, num_points//2):
    x.append(c_x)
    y.append(c_r*np.sin(theta) + c_y)
    z.append(c_r*np.cos(theta) + c_z + c_r)

for theta in np.linspace(-np.pi*2 , 0, num_points//2):
    x.append(c_x)
    y.append(c_r*np.sin(theta) + c_y)
    z.append(c_r*np.cos(theta) + c_z - c_r)

roll = np.repeat(roll, num_points)
pitch = np.repeat(pitch, num_points)
yaw = np.repeat(yaw, num_points)
t = np.linspace(0, max_time, num_points)
output = np.stack([t,x,y,z,roll,pitch,yaw])

with open("mick/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

with open("lite6/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

# %%
# params
roll,pitch,yaw = 0, np.pi/2, np.pi/2
c_x, c_y, c_z, c_r = 0.25, 0.0, 0.2, 0.1
header = "# timestamp x y z roll pitch yaw"
num_points = 1000
max_time = 50.0
filename = "eight_xy.txt"

x = []
y = []
z = []
for theta in np.linspace(np.pi*3, np.pi, num_points//2):
    x.append(c_r*np.sin(theta) + c_x)
    y.append(c_r*np.cos(theta) + c_y + c_r)
    z.append(c_z)

for theta in np.linspace(-np.pi*2 , 0, num_points//2):
    x.append(c_r*np.sin(theta) + c_x)
    y.append(c_r*np.cos(theta) + c_y - c_r)
    z.append(c_z)

roll = np.repeat(roll, num_points)
pitch = np.repeat(pitch, num_points)
yaw = np.repeat(yaw, num_points)
t = np.linspace(0, max_time, num_points)
output = np.stack([t,x,y,z,roll,pitch,yaw])

with open("mick/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)

with open("lite6/" + filename, 'w', encoding='UTF8', newline='') as f:
    f.write(header + "\n")
    writer = csv.writer(f, delimiter =' ')
    writer.writerows(output.T)
